# %%
import numpy as np
import rasterio as rio
import matplotlib.pyplot as plt
import os
import geopandas as gpd
from glob import glob

# %%
os.chdir("/Users/micha/ea-applications")
#(os.path.join("Users", "micha", "ea-applications"))

# %%
bad_sample_path = glob("sample-bad/*.jpg")
bad_sample_path
# Out:
# ['sample-bad\\BEVERLY_700833_Therm_147.jpg',
#  'sample-bad\\BEVERLY_700833_Therm_2.jpg',
#  'sample-bad\\BEVERLY_700833_Therm_422.jpg',
#  'sample-bad\\BEVERLY_700833_Therm_440.jpg',
#  'sample-bad\\BEVERLY_700833_Therm_466.jpg',
#  'sample-bad\\BEVERLY_700833_Therm_484.jpg',
#  'sample-bad\\MOTOROLA_704063_Therm_37.jpg',
#  'sample-bad\\TRACE_705761_Therm_71.jpg',
#  'sample-bad\\VALENCIA_706262_Therm_294.jpg']

# %%
for image in bad_sample_path:
    with rio.open(image) as src:
        bad = src.read()
        
        fig,ax = plt.subplots(1,2,figsize=(10,5))
        ax[0].imshow(bad[0], cmap = "jet")
        ax[1].hist(bad[0].flatten(), bins=100, facecolor='b', edgecolor='k', alpha=0.15)
        plt.show()
# Out:
# C:\Users\micha\Anaconda3\lib\site-packages\rasterio\__init__.py:216: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, **kwargs)

# %%
good_sample_path = glob("sample-good/*.jpg")
good_sample_path
# Out:
# ['sample-good\\BIRD_806937_Therm_1104 (1).jpg',
#  'sample-good\\CROSSBOW_707661_Therm_657.jpg',
#  'sample-good\\DEERFIELD BEACH_703541_Therm_377.jpg',
#  'sample-good\\DEERFIELD BEACH_703542_Therm_2718.jpg',
#  'sample-good\\HARRIS_203635_Therm_1175.jpg',
#  'sample-good\\MIAMI SHORES_803437_Therm_566.jpg',
#  'sample-good\\OAKLAND PARK_700438_Therm_933.jpg',
#  'sample-good\\POMPANO_700534_Therm_1715.jpg']

# %%
for image in good_sample_path:
    with rio.open(image) as src:
        good = src.read()
        
        fig,ax = plt.subplots(1,2,figsize=(10,5))
        ax[0].imshow(good[0], cmap = "jet")
        ax[1].hist(good[0].flatten(), bins=100, facecolor='b', edgecolor='k', alpha=0.15)
        plt.show()
# Out:
# C:\Users\micha\Anaconda3\lib\site-packages\rasterio\__init__.py:216: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, **kwargs)
